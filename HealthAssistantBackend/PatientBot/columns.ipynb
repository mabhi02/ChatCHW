# %%
import pandas as pd

# %%
df = pd.read_csv("Grading rubric WHO 2012 ChatGPT (1).xlsx - Rubric  (1).csv")

# %%
df.columns
# Out:
# Index(['True diagnosis ', 'Presents with', 'Required questions',
#        'Optional questions',
#        'Required exams <<May need to have "right" answer for this row>>',
#        'Final diagnosis', 'Treatment plan', 'Follow-up instructions'],
#       dtype='object')
